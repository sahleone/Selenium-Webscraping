# %%
import openai
from openai import embeddings
from dotenv import load_dotenv, find_dotenv
from unidecode import unidecode
from typing import Union, List


import os
import numpy as np
import pandas as pd

import torch

# %%
embeddingModel = 'text-embedding-3-small'

def get_embedding(text: str)->List[float]:
    text = text.replace("\n", " ")
    embedding = embeddings.create(
        input=text,
        model=embeddingModel
    )
    return embedding.data[0].embedding


def cosine_similarity(a, b):
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

# %%
data = pd.read_csv('data/df_all.csv')
data['embedding'] = data['embedding'].apply(eval).apply(np.array)
data.head()
# Out:
#                     jobTitle                                       company  \
# 0             Data Scientist                                        Zenith
# 1      Senior Data Scientist  Charlie Health Engineering, Product & Design
# 2  Machine Learning Engineer                                 FalconSmartIT
# 3             Data Scientist                                Morgan Stanley
# 4             Data Scientist                           City of Jersey City
#
#           location  date posted  \
# 0     New York, NY          NaN
# 1     New York, NY          NaN
# 2     New York, NY          NaN
# 3     New York, NY          NaN
# 4  Jersey City, NJ          NaN
#
#                                                 link  \
# 0  https://www.simplyhired.com/job/P_p1hn27u3cTsW...
# 1  https://www.simplyhired.com/job/ikx9-0RLxNfIx5...
# 2  https://www.simplyhired.com/job/OvfIVz13IToF5W...
# 3  https://www.simplyhired.com/job/zdQBTgDHV97jOa...
# 4  https://www.simplyhired.com/job/QW6PGA25yHL-mA...
#
#                                          description  \
# 0  Company Description\n\nZenith is the ROI Agenc...
# 1  Why Charlie Health?\nYoung people across the c...
# 2  Job Title: Machine Learning Engineer\nLocation...
# 3  Data Scientist\nJob Number:\n3245996\nPOSTING ...
# 4  Job Opening:\nData Scientist - Innovation\nDep...
#
#                                       qualifications date pulled  min_salary  \
# 0  Power BI||Microsoft Excel||Management||SAS||Re...         NaN       70000
# 1  TensorFlow||Growing experience||Management||Py...         NaN      148500
# 2  TensorFlow||Oracle||Kubernetes||RESTful API||P...         NaN      144000
# 3  Ontology||TensorFlow||Oracle||Statistics||Doct...         NaN      150000
# 4  ArcGIS||Microsoft Word||Microsoft Excel||Micro...         NaN       60000
#
#    max_salary                                          embedding
# 0      105000  [-0.0014290509279817343, 0.055856604129076004,...
# 1      228000  [-0.0016314274398609996, 0.002888173097744584,...
# 2      183000  [-0.02468576468527317, -0.02219345234334469, 0...
# 3      190000  [-0.015597617253661156, 0.015471013262867928, ...
# 4       67000  [-0.015759838744997978, 0.013187067583203316, ...

# %%
with open('Rhys Jervis Resume - Data Scientist (1).txt') as f:
    resume = f.read()

resume = unidecode(resume)

# %%
resume
# Out:
# "i>>?Irvington, NJ a(tm)| rhysjervis2@gmail.com a(tm)| 973-286-9351 a(tm)| github.com/sahleone  a(tm)| linkedin.com/in/rhys-jervis/\n________________\n\n\nData Scientist\nAccomplished Data Scientist Specializing in End-to-End Data Project Development\nProven and adaptable data scientist with a robust skill set dedicated to building comprehensive data projects from inception to implementation. Demonstrated success collaborating with cross-functional teams to deliver impactful results.\nSkills\n   Python (NumPy, Pandas, Scikit-learn, Stats models) | SQL/NoSQL | GIT \nAWS (EMR, S3) | Pytorch | Statistical Modeling | Machine Learning[a][b] | Forecasting\n\n\nTechnical Projects \n\n\nJob Posting Scraper and Recommendation Engine | Link                                             Present                                                    \n* Developed a web scraping module using Selenium to extract job postings from various websites.\n* Transformed the extracted data and stored it in a Vector Database\n[c][d]\n* Used the database to generate tailored job recommendations, enhancing the job search experience for users.\n\n\n\n\nProfessional Experience\nProspect 33, Manhattan, New York                                                                      2022 - 2023                                                      Data Scientist  \n* Acted as a data scientist for a R&D AI banking solution company, leveraging advanced data analytics and  machine learning techniques to drive innovation in the financial sector.\n* Conducted data extraction processes to gather relevant data from multiple sources, creating datasets for a machine learning pipeline and employee attrition, reducing data preprocessing time.\n* Developed the companyaEUR(tm)s first forecasting machine learning pipeline using Python, SQLAlchemy, Docker, Azure SQL, and Application Insights, achieving an 85% improvement in forecasting accuracy.\n* Collaborated with database administrators and domain experts to design an optimized database table schema that efficiently stores and manages forecasted results.\n* Led the forecasting product build, collaborating with customer success, and achieved a successful launch within 5 months, exceeding client expectations. \n\n\nFull-Time Student, Simplilearn                                                                          2021-2022\n\n\nMinistry of Health, Government of the Republic of Trinidad and Tobago                         2020-2021\nFreelance, Data Analyst\n* Served as a data analyst for the national authority and policymaker for all health systems, providing insights and data-driven recommendations to shape healthcare policies and improve national systems.\n* Designed a data dashboard for the Occupational Safety and Health department, evaluating the effectiveness of regional COVID-19 measures, resulting in improvement in safety protocols.\n* Launched a  questionnaire to assess the utilization of COVID-19 measures among 80 healthcare staff.\n* Conducted comprehensive data analysis and generated detailed reports during a 3-month project focused on assessing the effectiveness of COVID-19 safety measures, providing insights to leadership.\nFull-Time Student                                                                                          2018-2020\n\n\nUniversity of the West Indies, St. Augustine, Trinidad and Tobago                                      2018\nTeaching Assistant\n* Instructed a class of 30 undergraduate students in R programming, effectively equipping them with valuable data analysis skills.\n* Conducted in-depth reviews of lecture materials, enhancing students' academic performance, leading to an average class grade of B/B+ and 90% course completion. \n* Assisted with transcript marking and grade distribution, ensuring accurate recordkeeping for the course.\n\n\nEducation & Professional Development \n________________\n\n\nPost Graduate Program in Data Engineering Simplilearn with Purdue University, 2022\nMa ...

# %%
resumeEmbedding = get_embedding(resume)

# %%
data['cosine_similarity'] = data['embedding'].apply(lambda x: cosine_similarity(x, resumeEmbedding))
data['cosine_distance'] = 1 - data['cosine_similarity']

data.sort_values('cosine_distance', ascending=True, inplace=True)

# %%
data.head()
# Out:
#                                               jobTitle  \
# 111                                Senior Data Analyst
# 49                        Data Scientist - Hybrid - W2
# 69       Data Science Program Manager - SFL Scientific
# 57   Healthcare Artificial Intelligence Specialist,...
# 94   Scientist 3: Data Scientist (behavior change, ...
#
#                                company            location  date posted  \
# 111                    Open Road Media        New York, NY          NaN
# 49                          Ateeca Inc  Franklin Lakes, NJ          NaN
# 69                            Deloitte        New York, NY          NaN
# 57                                NJII          Newark, NJ          NaN
# 94   US Tech Solutions Private Limited   New Brunswick, NJ          NaN
#
#                                                   link  \
# 111  https://www.simplyhired.com/job/M7cjK3441tWBoT...
# 49   https://www.simplyhired.com/job/liX0Uu-5PKr_S0...
# 69   https://www.simplyhired.com/job/lpGth_CXLKBGsD...
# 57   https://www.simplyhired.com/job/sKpFFbnC4rM-ce...
# 94   https://www.simplyhired.com/job/sfahOgUOmhS1nb...
#
#                                            description  \
# 111  Essential Functions\nDevise mathematical model...
# 49   "#INDEED_A"\nDescription:\nHybrid to remote 3 ...
# 69   Data Science Program Manager, Specialist Maste...
# 57   Location\n100 summit street Newark, NJ, 07103,...
# 94   Duration: 12 months contract\nNotes about the ...
#
#                                         qualifications date pulled  \
# 111  Economics||Relational databases||R||Tableau||M...  2024-02-07
# 49   R||SQL||AWS||Bachelor's degree||Clinical trial...         NaN
# 69   Doctoral degree||Master's degree||Machine lear...  2024-02-01
# 57   TensorFlow||CI/CD||Statistics||PyTorch||Softwa...         NaN
# 94   Ontology||Doctoral degree||Analysis skills||Do...  2024-02-06
#
#      min_salary  max_salary  \
# 111      108306      108306
# 49        60000       67000
# 69       137000      173000
# 57       981000      124000
# 94         6017        6017
#
#                                              embedding  cosine_similarity  \
# 111  [-0.027259958907961845, 0.045442380011081696, ...           0.579271
# 49   [-0.045383162796497345, 0.015293051488697529, ...           0.573564
# 69   [0.008066137321293354, 0.020024465397000313, 0...           0.571437
# 57   [-0.04891146346926689, 0.0010793631663545966, ...           0.569102
# 94   [-0.02753903903067112, 0.029321731999516487, 0...           0.562508
#
#      cosine_distance
# 111         0.420729
# 49          0.426436
# 69          0.428563
# 57          0.430898
# 94          0.437492

# %% [markdown]
# # Database

# %%
def euclidean_distance(tensor1, tensor2):

    # np.linalg.norm(a - b)
    return torch.dist(tensor1, tensor2,p=2)

from torch.nn.functional import cosine_similarity 


def k_nearest_neighbors(query, tensor_list, k=None, metric = 'euclidean distance'):
    distances = []

    if k is None:
        k = len(tensor_list)

    if metric == 'euclidean distance':
        for i, tensor in enumerate(tensor_list):
            distances.append([i,euclidean_distance(query, tensor)])
    
    elif metric == 'cosine similarity':
        for i, tensor in enumerate(tensor_list):
            distances.append([i,cosine_similarity(query, tensor)])
        
    distances.sort(key=lambda x: x[1])
    return distances[:k]

# sklearn NearestNeighbors maybe

# %%
from lancedb.pydantic import LanceModel, vector

# %%
class JobPosting(LanceModel):
    jobTitle: str
    link: str
    description: str
    min_salary: int
    embedding: vector(1536)

# %%
import lancedb

db = lancedb.connect('~/.jobs.db')
table_name = "job_posting"
db.drop_table(table_name, ignore_missing=True)
table = db.create_table(table_name,schema=JobPosting)

# %%
table.add(data[['jobTitle', 'link', 'description', 'min_salary', 'embedding']])

# %%
type(resumeEmbedding)
# Out:
# list

# %%
table.search(np.array(resumeEmbedding),vector_column_name="embedding").limit(5).to_pandas()
# Out:
#                                             jobTitle  \
# 0                                Senior Data Analyst
# 1                       Data Scientist - Hybrid - W2
# 2      Data Science Program Manager - SFL Scientific
# 3  Healthcare Artificial Intelligence Specialist,...
# 4  Scientist 3: Data Scientist (behavior change, ...
#
#                                                 link  \
# 0  https://www.simplyhired.com/job/M7cjK3441tWBoT...
# 1  https://www.simplyhired.com/job/liX0Uu-5PKr_S0...
# 2  https://www.simplyhired.com/job/lpGth_CXLKBGsD...
# 3  https://www.simplyhired.com/job/sKpFFbnC4rM-ce...
# 4  https://www.simplyhired.com/job/sfahOgUOmhS1nb...
#
#                                          description  min_salary  \
# 0  Essential Functions\nDevise mathematical model...      108306
# 1  "#INDEED_A"\nDescription:\nHybrid to remote 3 ...       60000
# 2  Data Science Program Manager, Specialist Maste...      137000
# 3  Location\n100 summit street Newark, NJ, 07103,...      981000
# 4  Duration: 12 months contract\nNotes about the ...        6017
#
#                                            embedding  _distance
# 0  [-0.027259959, 0.04544238, 0.07065169, 0.00478...   0.841458
# 1  [-0.045383163, 0.0152930515, 0.08823126, 0.005...   0.852871
# 2  [0.008066137, 0.020024465, 0.051869657, -0.000...   0.857125
# 3  [-0.048911463, 0.0010793632, 0.055022117, 0.00...   0.861796
# 4  [-0.027539039, 0.029321732, 0.01764153, 0.0293...   0.874984
